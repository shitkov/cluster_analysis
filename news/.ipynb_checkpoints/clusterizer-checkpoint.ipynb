# %% [markdown]
# <a href="https://colab.research.google.com/github/shitkov/cluster_analysis/blob/master/news/clusterizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/shitkov/cluster_analysis/master/news/news.txt
# Out:
# --2022-06-13 10:46:10--  https://raw.githubusercontent.com/shitkov/cluster_analysis/master/news/news.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50155 (49K) [text/plain]
# Saving to: 'news.txt.1'
#
# news.txt.1          100%[===================>]  48.98K  --.-KB/s    in 0.05s
#
# 2022-06-13 10:46:10 (997 KB/s) - 'news.txt.1' saved [50155/50155]

# %%
# !wget https://raw.githubusercontent.com/shitkov/cluster_analysis/master/news/clusterizer.py
# Out:
# --2022-06-13 10:46:14--  https://raw.githubusercontent.com/shitkov/cluster_analysis/master/news/clusterizer.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3639 (3.6K) [text/plain]
# Saving to: 'clusterizer.py.1'
#
# clusterizer.py.1    100%[===================>]   3.55K  --.-KB/s    in 0.01s
#
# 2022-06-13 10:46:14 (312 KB/s) - 'clusterizer.py.1' saved [3639/3639]

# %%
# !wget https://raw.githubusercontent.com/shitkov/cluster_analysis/master/news/requirements.txt
# Out:
# --2022-06-13 10:46:17--  https://raw.githubusercontent.com/shitkov/cluster_analysis/master/news/requirements.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: 'requirements.txt.1'
#
# requirements.txt.1  100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-06-13 10:46:18 (2.24 MB/s) - 'requirements.txt.1' saved [54/54]

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (1.21.5)
# Requirement already satisfied: pandas in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.4.2)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied: torch in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (1.11.0)
# Requirement already satisfied: transformers in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (4.19.4)
# Requirement already satisfied: sentencepiece in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (0.1.96)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 2)) (2021.3)
# Requirement already satisfied: scikit-learn in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from sklearn->-r requirements.txt (line 3)) (1.0.2)
# Requirement already satisfied: typing-extensions in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (4.1.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 5)) (2022.3.15)
# Requirement already satisfied: requests in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 5)) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 5)) (6.0)
# Requirement already satisfied: filelock in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 5)) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 5)) (21.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->transformers->-r requirements.txt (line 5)) (3.0.4)
# Requirement already satisfied: six>=1.5 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from requests->transformers->-r requirements.txt (line 5)) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from requests->transformers->-r requirements.txt (line 5)) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from requests->transformers->-r requirements.txt (line 5)) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from requests->transformers->-r requirements.txt (line 5)) (2021.10.8)
# Requirement already satisfied: joblib>=0.11 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 3)) (2.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /Users/panda/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 3)) (1.7.3)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=1bab26e4d855d6683a31c83ae05c7883cd718037b69ec5d549a64598193055b8
#   Stored in directory: /Users/panda/Library/Caches/pip/wheels/e4/7b/98/b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0

# %%
from clusterizer import Clusterizer

# %%
with open('news.txt') as f:
    texts = [line.rstrip('\n') for line in f]

# %%
# or downloads localy files from https://huggingface.co/cointegrated/LaBSE-en-ru/tree/main
cls = Clusterizer('cointegrated/LaBSE-en-ru')
# Out:
# Downloading:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cointegrated/LaBSE-en-ru were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/509k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
top = cls.predict([])
# Out:
# Get texts embeddings:
# 0it [00:00, ?it/s]
# Calculating the optimal number of clusters:
# 0it [00:00, ?it/s]

# %%
top
# Out:
# ['Редактор The Economist Джоши заявил, что ВСУ потеряли много иностранной артиллерии',
#  'Минобороны показало кадры поражения на Украине артиллерийской установки M109 из Норвегии',
#  'Посол ЛНР в России сообщил о зачистке Северодонецка',
#  'Во Франции заявили о неминуемой победе России в спецоперации',
#  'Небензя покинул зал Совбеза ООН во время выступления главы Евросовета Мишеля',
#  'Кадыров заявил о «массированном наступлении» на позиции ВСУ в ЛНР',
#  'Минобороны сообщило о завершении взятия Святогорска в ДНР',
#  'Iltalehti: Макрон напугал Украину одной фразой о России',
#  'МВД объявило в розыск Глуховского и Милова',
#  '«Известия»: в АПЭК спрогнозировали отставки пяти российских губернаторов осенью 2022 года',
#  'Джонсон сохранил посты лидера партии и премьера Великобритании',
#  'Синод РПЦ снял митрополита Илариона с должностей',
#  'Вучич заявил о просьбах отменить визит Лаврова в Сербию',
#  'Джо Байден объявил режим ЧС из-за угрозы дефицита электромощностей в США',
#  'Россия приостанавливает соглашение с Японией о промысле морских живых ресурсов',
#  'Замглавы херсонской ВГА Стремоусов: в регионе пройдет референдум о вхождении в Россию',
#  'Дудь подал иск к Минюсту о неуведомлении при признании его иноагентом',
#  'Путин сообщил о взятой под контроль ситуации с инфляцией в РФ',
#  'Президент Зеленский признал сдачу в плен 2500 военных ВСУ с «Азовстали»',
#  'МИД Японии заявил о введении санкций против Россельхозбанка и Московского кредитного банка',
#  'Financial Times: Зеленский снова подтвердил, что открыт к мирным переговорам с Путиным',
#  'МИД России расширил стоп-лист в отношении граждан США, в список внесен еще 61 человек',
#  'Шойгу сообщил об открытии автомобильного движения в Крым по материку',
#  'Зеленский заявил, что мир устал от ситуации на Украине',
#  'Военный прокурор Егиев заявил о наказании 12 офицеров за участие срочников в СВО',
#  'Конгресс ISU поднял возрастной ценз в фигурном катании до 17 лет',
#  'Джонсон назвал «решающими» для страны итоги голосования о вотуме доверия',
#  'Постпред в Вене: Россия не станет ассоциировать себя с резолюцией МАГАТЭ по Ирану',
#  'Onet.pl: введенные Польшей антироссийские санкции приведут к экологической катастрофе',
#  'Глава МИД Италии назвал заявление Медведева угрозой в адрес тех, кто стремится к миру',
#  'Economist сообщил о прекращении работы IBM в России',
#  'Замглавы Минобрнауки Афанасьев сообщил об исключении российских вузов из Болонской системы',
#  'Блинкен обвинил Россию в проблемах с вывозом зерна с Украины',
#  'Шойгу сообщил о сдаче в плен 6,5 тыс. украинских военных',
#  'Польша подпишет крупнейший за 30 лет контракт на поставку вооружения Киеву',
#  'Экспортерам в РФ разрешили получать валютную выручку на зарубежные счета',
#  'Польша предложила включить в 7-й пакет санкций ЕС все энергоносители и банки России',
#  'В Белоруссии начались тренировки по переводу с мирного на военное время',
#  '«Лукойл» переведет купленные у Shell АЗС под финский бренд Teboil',
#  'Журналист Травальо: Россия одерживает победу над ВСУ',
#  'Первые 15 точек нового McDonald’s откроются в Москве и Подмосковье 12 июня',
#  'Песков опроверг данные о нежелании Москвы обсуждать статус Запорожья и Херсона',
#  'Минцифры перенаправит интернет-трафик через Азию в случае отключения от европейской сети',
#  'Наставник «Сочи» Федотов станет главным тренером ЦСКА',
#  'Пушилин: британским наемникам на заседании суда в ДНР предъявили обвинения',
#  'Медведев объяснил резкость своих постов в Telegram-канале',
#  'США усомнились в решении проблемы с зерном после визита Лаврова в Турцию',
#  'Apple представила iOS 16 с новым экраном блокировки и системой виджетов',
#  'Скончался космонавт Валерий Рюмин, совершивший четыре полета',
#  'Кабмин Японии заявил о намерении сохранить участие в проектах «Сахалин-1» и «Сахалин-2»',
#  '«Уральские авиалинии» отменили рейсы в шесть южных городов России с 1 июля до 30 сентября',
#  'Прокурор запросил 20 лет главному фигуранту дела о хищениях на стройке в Ново-Огарево',
#  'Компания Apple представила новый процессор M2, который быстрее предыдущего на 35%',
#  'WP узнала о тайном строительстве Китаем военно-морской базы в Камбодже',
#  '«Ъ»: в Страсбурге сообщили, что Россия задолжала €74 млн компенсаций по решениям ЕСПЧ',
#  'Global Times: США больше не хотят победы Украины и стремятся создать мировой хаос']
