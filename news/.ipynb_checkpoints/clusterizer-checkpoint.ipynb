# %% [markdown]
# <a href="https://colab.research.google.com/github/shitkov/cluster_analysis/blob/master/news/clusterizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from clusterizer import Clusterizer

# %%
with open('news.txt') as f:
    texts = [line.rstrip('\n') for line in f]

# %%
# or downloads localy files from https://huggingface.co/cointegrated/LaBSE-en-ru/tree/main
cls = Clusterizer('cointegrated/LaBSE-en-ru');
# Out:
# Some weights of the model checkpoint at cointegrated/LaBSE-en-ru were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
top = cls.predict(texts[:5])
# Out:
# Get texts embeddings:
# 100%|██████████████████████████████████████| 30/30 [00:02<00:00, 13.72it/s]
# Calculating the optimal number of clusters:
#   0%|                                               | 0/28 [00:00<?, ?it/s]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  11%|████▏                                  | 3/28 [00:01<00:10,  2.46it/s]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  14%|█████▌                                 | 4/28 [00:02<00:16,  1.48it/s]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
# /Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
# /Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  25%|█████████▊                             | 7/28 [00:02<00:06,  3.24it/s]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
# /Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  32%|████████████▌                          | 9/28 [00:02<00:04,  4.55it/s]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (11). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
# /Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (12). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  39%|██████████████▉                       | 11/28 [00:02<00:02,  5.91it/s]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (13). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
# /Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (14). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  46%|█████████████████▋                    | 13/28 [00:03<00:02,  7.15it/s]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (15). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
# /Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (16). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  54%|████████████████████▎                 | 15/28 [00:03<00:01,  7.99it/s]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (17). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
# /Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (18). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  61%|███████████████████████               | 17/28 [00:03<00:01,  8.16it/s]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (19). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
# /Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  68%|█████████████████████████▊            | 19/28 [00:07<00:06,  1.45it/s]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (21). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  71%|███████████████████████████▏          | 20/28 [00:09<00:07,  1.10it/s]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (22). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  75%|████████████████████████████▌         | 21/28 [00:11<00:07,  1.11s/it]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (23). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  79%|█████████████████████████████▊        | 22/28 [00:13<00:07,  1.30s/it]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (24). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  82%|███████████████████████████████▏      | 23/28 [00:15<00:07,  1.49s/it]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (25). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  86%|████████████████████████████████▌     | 24/28 [00:17<00:06,  1.70s/it]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (26). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  89%|█████████████████████████████████▉    | 25/28 [00:19<00:05,  1.88s/it]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (27). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  93%|███████████████████████████████████▎  | 26/28 [00:22<00:03,  1.97s/it]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (28). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
#  96%|████████████████████████████████████▋ | 27/28 [00:24<00:02,  2.07s/it]/Users/panda/github/cluster_analysis/news/clusterizer.py:49: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (29). Possibly due to duplicate points in X.
#   metrics.append((KMeans(n_clusters=i, random_state=42).fit(embeddings)).inertia_)
# 100%|██████████████████████████████████████| 28/28 [00:26<00:00,  1.06it/s]

# %%
top
# Out:
# ['папа ел людей ложкой']
